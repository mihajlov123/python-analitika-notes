# %% [markdown]
# # Prikazovanje podatkov - osnonvo

# %% [markdown]
# ## Representation Of Data

# %% [markdown]
# ## Introduction To The Data

# %%
! dir data
# Out:
# fandango_scores.csv  graf2.PNG	graf4.PNG	  unrate.csv
# graf1.PNG	     graf3.PNG	recent-grads.csv

# %%
import pandas as pd
import numpy as np

# %%
unrate = pd.read_csv("data/unrate.csv")

# %%
unrate
# Out:
#            DATE  VALUE
# 0    1948-01-01    3.4
# 1    1948-02-01    3.8
# 2    1948-03-01    4.0
# 3    1948-04-01    3.9
# 4    1948-05-01    3.5
# ..          ...    ...
# 819  2016-04-01    5.0
# 820  2016-05-01    4.7
# 821  2016-06-01    4.9
# 822  2016-07-01    4.9
# 823  2016-08-01    4.9
#
# [824 rows x 2 columns]

# %%
unrate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824 entries, 0 to 823
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    824 non-null    object
#  1   VALUE   824 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 13.0+ KB

# %%
# pretvorimo object -> date
unrate["DATE"] = pd.to_datetime(unrate["DATE"])
unrate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824 entries, 0 to 823
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    824 non-null    datetime64[ns]
#  1   VALUE   824 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 13.0 KB

# %% [markdown]
# ## Introduction to matplotlib

# %% [markdown]
# ### Ostale uporabne knjiznice
# - seaborn
# - bokeh
# - plotly

# %%
# ukaz za to da se grafi lepše prikazujejo v jupyter notebook
# %matplotlib inline  
import matplotlib.pyplot as plt

# %%
import matplotlib # dokumentacija https://matplotlib.org/
print(f'matplotlib: {matplotlib.__version__}')
# Out:
# matplotlib: 3.6.2

# %%
plt.plot()
plt.show()

# %% [markdown]
# ## Axis Ticks

# %%
first_data = unrate[0:36]
first_data
# Out:
#          DATE  VALUE
# 0  1948-01-01    3.4
# 1  1948-02-01    3.8
# 2  1948-03-01    4.0
# 3  1948-04-01    3.9
# 4  1948-05-01    3.5
# 5  1948-06-01    3.6
# 6  1948-07-01    3.6
# 7  1948-08-01    3.9
# 8  1948-09-01    3.8
# 9  1948-10-01    3.7
# 10 1948-11-01    3.8
# 11 1948-12-01    4.0
# 12 1949-01-01    4.3
# 13 1949-02-01    4.7
# 14 1949-03-01    5.0
# 15 1949-04-01    5.3
# 16 1949-05-01    6.1
# 17 1949-06-01    6.2
# 18 1949-07-01    6.7
# 19 1949-08-01    6.8
# 20 1949-09-01    6.6
# 21 1949-10-01    7.9
# 22 1949-11-01    6.4
# 23 1949-12-01    6.6
# 24 1950-01-01    6.5
# 25 1950-02-01    6.4
# 26 1950-03-01    6.3
# 27 1950-04-01    5.8
# 28 1950-05-01    5.5
# 29 1950-06-01    5.4
# 30 1950-07-01    5.0
# 31 1950-08-01    4.5
# 32 1950-09-01    4.4
# 33 1950-10-01    4.2
# 34 1950-11-01    4.2
# 35 1950-12-01    4.3

# %%
first_data = unrate[0:36]
plt.plot(first_data["DATE"],first_data["VALUE"])
plt.xticks(rotation=45)
plt.show()

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %% [markdown]
# ### Fixing Axis Ticks

# %%
first_data = unrate[0:36]
plt.plot(first_data["DATE"],first_data["VALUE"])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Adding Axis Labels And A Title

# %%
first_data = unrate[0:822]
plt.plot(first_data["DATE"],first_data["VALUE"])
plt.xticks(rotation=45)
plt.xlabel("month")
plt.ylabel("uneployment rate")
plt.title("Monthly unemployment rate")
plt.show()

# %% [markdown]
# ## Matplotlib Classes

# %% [markdown]
# axes_obj = fig.add_subplot(nrows, ncols, plot_nmumber) -> prvi dve vrednosti samo definirata shape, tretji argument pove za kateri določamo

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,1,1) # dve vrstici, en stolpcev, 1. graf
ax2 = fig.add_subplot(2,1,2) # dve vrstici, en stolpcev, 2. graf

# %% [markdown]
# ## Grid Positioning

# %% [markdown]
# <p><img alt="Multiple Subplots" src="images/multiple_subplots.png"></p>
#
# <p><img alt="Subplot Grid" src="images/subplot_grid.png"></p>
#
# <p><img alt="Missing One Plot" src="images/multiple_subplots_missing_one_plot.png"></p></div>

# %% [markdown]
# ## Adding Data

# %%
first_twelve = unrate[0:12]
second_twelve = unrate[12:24]
first_twelve
# Out:
#          DATE  VALUE
# 0  1948-01-01    3.4
# 1  1948-02-01    3.8
# 2  1948-03-01    4.0
# 3  1948-04-01    3.9
# 4  1948-05-01    3.5
# 5  1948-06-01    3.6
# 6  1948-07-01    3.6
# 7  1948-08-01    3.9
# 8  1948-09-01    3.8
# 9  1948-10-01    3.7
# 10 1948-11-01    3.8
# 11 1948-12-01    4.0

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)
ax1.plot(first_twelve["DATE"], first_twelve["VALUE"])
ax2.plot(first_twelve["DATE"], first_twelve["VALUE"])

# %% [markdown]
# ## Formatting And Spacing

# %%
fig = plt.figure(figsize=(12,8))

NUM_OF_YEARS = 5

for i in range(NUM_OF_YEARS):
    ax = fig.add_subplot(NUM_OF_YEARS,1,i+1)
    start_index = i*12
    end_index = (i+1) * 12
    subset = unrate[start_index:end_index]
    ax.plot(subset["DATE"], subset["VALUE"])
    ax.set_title(f"Monthly Unemployment Rate, {1948 + i}")
plt.show()

# ax1 = fig.add_subplot(2,1,1)
# ax2 = fig.add_subplot(2,1,2)
# ax1.plot(unrate[0:12]["DATE"], unrate[0:12]["VALUE"])
# ax1.set_title('Monthly unemployment Rate, 1948')
# ax2.plot(unrate[12:24]["DATE"], unrate[12:24]["VALUE"])
# ax2.set_title('Monthly unemployment Rate, 1949')





plt.show()

# %% [markdown]
# ## Comparing Across More Years

# %% [markdown]
# ## Overlaying Line Charts

# %%
unrate["MONTH"] = unrate["DATE"].dt.month
unrate
# Out:
#           DATE  VALUE  MONTH
# 0   1948-01-01    3.4      1
# 1   1948-02-01    3.8      2
# 2   1948-03-01    4.0      3
# 3   1948-04-01    3.9      4
# 4   1948-05-01    3.5      5
# ..         ...    ...    ...
# 819 2016-04-01    5.0      4
# 820 2016-05-01    4.7      5
# 821 2016-06-01    4.9      6
# 822 2016-07-01    4.9      7
# 823 2016-08-01    4.9      8
#
# [824 rows x 3 columns]

# %%
fig = plt.figure(figsize=(6,3))
plt.plot(unrate[0:12]["MONTH"], unrate[0:12]["VALUE"], c='red')
plt.plot(unrate[12:24]["MONTH"], unrate[12:24]["VALUE"], c='blue')
plt.show()

# %%
fig = plt.figure(figsize=(12,8))

colors = ['red', 'blue', 'green', 'orange', 'black']
NUM_OF_YEARS = 5

for i in range(NUM_OF_YEARS):
    start_index = i*12
    end_index = (i+1) * 12
    subset = unrate[start_index:end_index]
    plt.plot(subset["MONTH"], subset["VALUE"], c=colors[i])
plt.show()

# %% [markdown]
# ## Adding A Legend

# %%
fig = plt.figure(figsize=(10,6))
colors = ['red', 'blue', 'green', 'orange', 'black']
for i in range(5):
    start_index = i*12
    end_index = (i+1)*12
    subset = unrate[start_index:end_index]
    label = str(1948 + i)
    plt.plot(subset['MONTH'], subset['VALUE'], c=colors[i], label=label)    
    
plt.legend(loc="upper left", title="Year", title_fontsize="small", shadow=True, fontsize="small")  
plt.show()

# %%
fig = plt.figure(figsize=(10,6))
colors = ['red', 'blue', 'green', 'orange', 'black']
for i in range(5):
    start_index = i*12
    end_index = (i+1)*12
    subset = unrate[start_index:end_index]
    label = str(1948 + i)
    plt.plot(subset['MONTH'], subset['VALUE'], c=colors[i], label=label)

plt.legend(loc='upper left')
plt.title("Monthly Unemployment Trends, 1948-1952")
plt.xlabel("Month, Integer")
plt.ylabel("Unemployment Rate, Percent")
plt.show()

# %% [markdown]
# ## Introduction to the data

# %%
import pandas as pd

# %%
reviews = pd.read_csv('data/fandango_scores.csv')

# %%
cols = ['FILM', 'RT_user_norm', 'Metacritic_user_nom', 
        'IMDB_norm', 'Fandango_Ratingvalue', 'Fandango_Stars']

# %%
norm_reviews = reviews[cols].copy()

# %% [markdown]
# ## Bar Plots

# %% [markdown]
# <p><img alt="Vertical Bar Plot" src="images/vertical_bar_plot.png"></p>
#
#
# <p><img alt="Horizontal Bar Plot" src="images/horizontal_bar_plot.png"></p>

# %% [markdown]
# ### Creating Bars

# %% [markdown]
# <p><img alt="Matplotlib Barplot Positioning" src="images/matplotlib_barplot_positioning.png"></p>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from numpy import arange

# %%
# Positions of the left sides of the 5 bars. [0.75, 1.75, 2.75, 3.75, 4.75]
bar_positions = arange(5) + 0.75
tick_positions = range(1,6)

# %%
# Heights of the bars.  In our case, the average rating for the first movie in the dataset.
num_cols = ['RT_user_norm', 'Metacritic_user_nom', 'IMDB_norm', 'Fandango_Ratingvalue', 'Fandango_Stars']
bar_heights = reviews[num_cols].iloc[0].values

# %% [markdown]
# ### Aligning Axis Ticks And Labels

# %%
fig, ax = plt.subplots()
ax.bar(bar_positions, bar_heights, width=0.5, align="edge")
ax.set_xticks(tick_positions)
ax.set_xticklabels(num_cols, rotation=90)
ax.set_xlabel("Rating Source")
ax.set_ylabel("Average Rating")
ax.set_title('Average User Rating For Avengers: Age of Ultron (2015)')
plt.show()

# %% [markdown]
# ### Horizontal Bar Plot

# %%
num_cols = ['RT_user_norm', 'Metacritic_user_nom', 'IMDB_norm', 'Fandango_Ratingvalue', 'Fandango_Stars']
bar_widths = reviews[num_cols].iloc[0].values
bar_positions = arange(5) + 0.75
tick_positions = range(1,6)

# %%
fig, ax = plt.subplots()

ax.barh(bar_positions, bar_widths, height = 0.5, align="edge")
ax.set_yticks(tick_positions)
ax.set_yticklabels(num_cols)
ax.set_ylabel("Rating Source")
ax.set_xlabel("Average Rating")
ax.set_title('Average User Rating For Avengers: Age of Ultron (2015)')
plt.show()

# %% [markdown]
# ## Scatter plot

# %% [markdown]
# <p><img alt="Imgur" src="images/scatter_plot_intro.png"></p>

# %%
fig, ax = plt.subplots()

ax.scatter(reviews['Fandango_Ratingvalue'], reviews['RT_user_norm']) # vsaka točka predstavlja en film

ax.set_xlabel("Fandango")
ax.set_ylabel("Rotten Tomatoes")
ax.set_title("Korelacija ocen med Fandango in Rotten tomatoes")
plt.show()

# %% [markdown]
# ### Switching axes

# %%
fig = plt.figure(figsize=(5,10))
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)


ax1.set_xlabel("Fandango")
ax1.set_ylabel("Rotten Tomatoes")



ax2.set_xlabel("Rotten Tomatoes")
ax2.set_ylabel("Fandango")
plt.show()

# %% [markdown]
# ### Benchmarking correlation

# %%
norm_reviews = reviews
fig = plt.figure(figsize=(5,10))
ax1 = fig.add_subplot(3,1,1)
ax2 = fig.add_subplot(3,1,2)
ax3 = fig.add_subplot(3,1,3)

ax1.scatter(norm_reviews['Fandango_Ratingvalue'], norm_reviews['RT_user_norm'])
ax1.set_xlabel("Fandango")
ax1.set_ylabel("Rotten Tomatoes")
ax1.set_xlim(0, 5)
ax1.set_ylim(0, 5)

ax2.scatter(norm_reviews['Fandango_Ratingvalue'], norm_reviews['Metacritic_user_nom'])
ax2.set_xlabel("Fandango")
ax2.set_ylabel("Metacritic")
ax2.set_xlim(0, 5)
ax2.set_ylim(0, 5)

ax3.scatter(norm_reviews['Fandango_Ratingvalue'], norm_reviews['IMDB_norm'])
ax3.set_xlabel("Fandango")
ax3.set_ylabel("IMDB")
ax3.set_xlim(0, 5)
ax3.set_ylim(0, 5)

plt.show()

# %% [markdown]
# ## Histogram

# %% [markdown]
# ### Frequency Distribution

# %%
freq_counts = norm_reviews["Fandango_Ratingvalue"].value_counts().sort_index()
freq_counts
# Out:
# 2.7     2
# 2.8     2
# 2.9     5
# 3.0     4
# 3.1     3
# 3.2     5
# 3.3     4
# 3.4     9
# 3.5     9
# 3.6     8
# 3.7     9
# 3.8     5
# 3.9    12
# 4.0     7
# 4.1    16
# 4.2    12
# 4.3    11
# 4.4     7
# 4.5     9
# 4.6     4
# 4.8     3
# Name: Fandango_Ratingvalue, dtype: int64

# %% [markdown]
# ### Binning

# %% [markdown]
# <p><img alt="Binning Introduction" src="images/histogram_binning.png"></p>

# %% [markdown]
# ### Histogram In Matplotlib

# %%
fig, ax = plt.subplots()
ax.hist(norm_reviews["Fandango_Ratingvalue"], range=(0,5), bins=10)
plt.show()

# %%
# Vaja - nov stolpec s povprečnimi ocena, naredi histogram iz tega stolpca
# pozor -> ce norm_revies ne bi definirali preko copy metode bi dobili copy warning
norm_reviews['Norm_mean'] = norm_reviews.mean(axis=1, numeric_only=True) # numeric_only = True odstrani deprecation oz. future warning
fig, ax = plt.subplots()
ax.hist(norm_reviews["Norm_mean"], range=(0,5), bins=10)
plt.show()

# %% [markdown]
# ### Comparing histograms

# %%
fig = plt.figure(figsize=(5,20))
ax1 = fig.add_subplot(4,1,1)
ax2 = fig.add_subplot(4,1,2)
ax3 = fig.add_subplot(4,1,3)
ax4 = fig.add_subplot(4,1,4)

ax1.hist(norm_reviews['Fandango_Ratingvalue'], bins=20, range=(0,5))
ax1.set_title('Distribution of Fandango Ratings')
ax1.set_ylim(0,50)

ax2.hist(norm_reviews['RT_user_norm'], bins=20, range=(0,5))
ax2.set_title('Distribution of Rotten Tomatoes Ratings')
ax2.set_ylim(0,50)

ax3.hist(norm_reviews['Metacritic_user_nom'], bins=20, range=(0,5))
ax3.set_title('Distribution of Metacritic Ratings')
ax3.set_ylim(0,50)

ax4.hist(norm_reviews['IMDB_norm'], bins=20, range=(0,5))
ax4.set_title('Distribution of IMDB Ratings')
ax4.set_ylim(0,50)

plt.show()

# %% [markdown]
# ### Quartiles

# %% [markdown]
# ## Box Plot

# %% [markdown]
# <p><img alt="Boxplot" src="images/boxplot_intro.png"></p>

# %%
fig, ax = plt.subplots()
ax.boxplot(norm_reviews["RT_user_norm"])
ax.set_xticklabels(['Rotten Tomatoes'])
ax.set_ylim(0,5)
plt.show()

# %% [markdown]
# ### Multiple Box Plots

# %%
num_cols = ['RT_user_norm', 'Metacritic_user_nom', 'IMDB_norm', 'Fandango_Ratingvalue']

fig, ax = plt.subplots()
ax.boxplot(norm_reviews[num_cols].values)
ax.set_xticklabels(num_cols, rotation=90)
ax.set_ylim(0,5)
plt.show()
