# %% [markdown]
# # Prikazovanje podatkov - napredno

# %% [markdown]
# ## Improving Plot Aesthetics

# %% [markdown]
# ### Introduction To The Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
women_degrees = pd.read_csv('data/percent-bachelors-degrees-women-usa.csv')

# %%
women_degrees.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %%
women_degrees.tail()
# Out:
#     Year  Agriculture  Architecture  Art and Performance    Biology  \
# 37  2007    47.605026     43.100459                 61.4  59.411993
# 38  2008    47.570834     42.711730                 60.7  59.305765
# 39  2009    48.667224     43.348921                 61.0  58.489583
# 40  2010    48.730042     42.066721                 61.3  59.010255
# 41  2011    50.037182     42.773438                 61.2  58.742397
#
#      Business  Communications and Journalism  Computer Science  Education  \
# 37  49.000459                           62.5              17.6  78.721413
# 38  48.888027                           62.4              17.8  79.196327
# 39  48.840474                           62.8              18.1  79.532909
# 40  48.757988                           62.5              17.6  79.618625
# 41  48.180418                           62.2              18.2  79.432812
#
#     Engineering    English  Foreign Languages  Health Professions  \
# ...

# %%
plt.plot(women_degrees["Year"],women_degrees["Biology"], c='blue', label='Women')
plt.plot(women_degrees["Year"],100-women_degrees["Biology"], c='green', label='Men')
plt.legend(loc='upper right')
plt.title('Percentage of Biology Degrees Awarded By Gender')
plt.show()

# %% [markdown]
# ### Hiding Tick Marks

# %%
fig, ax = plt.subplots()

ax.plot(women_degrees["Year"],women_degrees["Biology"], c='blue', label='Women')
ax.plot(women_degrees["Year"],100-women_degrees["Biology"], c='green', label='Men')

ax.tick_params(bottom=False, top=False, right=False, left = False)
plt.legend(loc='upper right')
plt.title('Percentage of Biology Degrees Awarded By Gender')
plt.show()

# %% [markdown]
# ### Hiding Spines

# %%
fig, ax = plt.subplots()
ax.spines

# %%
fig, ax = plt.subplots()
ax.plot(women_degrees['Year'], women_degrees['Biology'], label='Women')
ax.plot(women_degrees['Year'], 100-women_degrees['Biology'], label='Men')
ax.tick_params(bottom=False, top=False, left=False, right=False)


# skrijemo okvir (vse stiri stranice grafa - spines)
for key, spine in ax.spines.items():
    spine.set_visible(False)

    
ax.legend(loc='upper right')
ax.set_title('Percentage of Biology Degrees Awarded By Gender')
plt.show()

# %% [markdown]
# ### Comparing data with multiple plots

# %%
major_cats = ['Biology', 'Computer Science', 'Engineering', 'Math and Statistics']
fig = plt.figure(figsize=(12, 12))

for i in range(0,4):
    ax=fig.add_subplot(2,2,i+1)
    ax.plot(women_degrees['Year'], women_degrees[major_cats[i]], label='Women')
    ax.plot(women_degrees['Year'], 100-women_degrees[major_cats[i]], label='Men')
    ax.set_title(major_cats[i])
    ax.tick_params(bottom=False, top=False, left=False, right=False)
    # skrijemo okvir (vse stiri stranice grafa - spines)
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    plt.legend(loc='upper right')   

# Calling pyplot.legend() here will add the legend to the last subplot that was created.
# plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## Color, Layout, and Annotations

# %% [markdown]
# ### Color

# %% [markdown]
# ### Setting Line Color Using RGB

# %%
fig = plt.figure(figsize=(12, 12))

for sp in range(0,4):
    ax = fig.add_subplot(2,2,sp+1)
    cb_dark_blue = (0/255, 107/255, 164/255)
    cb_orange = (255/255, 128/255,14/255)
    ax.plot(women_degrees['Year'], women_degrees[major_cats[sp]], c=cb_dark_blue, label='Women')
    ax.plot(women_degrees['Year'], 100-women_degrees[major_cats[sp]], c=cb_orange, label='Men')
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    # postavimo x in y limite na oseh za lazjo primerjavo
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(major_cats[sp])
    ax.tick_params(bottom=False, top=False, left=False, right=False)

plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### Setting Line Width

# %%
cb_dark_blue = (0/255, 107/255, 164/255)
cb_orange = (255/255, 128/255, 14/255)

fig = plt.figure(figsize=(12, 12))

for sp in range(0,4):
    ax = fig.add_subplot(2,2,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[major_cats[sp]], linewidth=6, c=cb_dark_blue, label='Women')
    ax.plot(women_degrees['Year'], 100-women_degrees[major_cats[sp]], linewidth=3, c=cb_orange, label='Men')
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(major_cats[sp])
    ax.tick_params(bottom=False, top=False, left=False, right=False)

plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### Improve the Layout and Ordering

# %%
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(21, 4))

for sp in range(0,len(stem_cats)):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], linewidth=3, c=cb_dark_blue, label='Women')
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], linewidth=3, c=cb_orange, label='Men')
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom=False, top=False, left=False, right=False)

plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### Replacing the Legend With Annotations

# %%
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(21, 4))

for sp in range(0,len(stem_cats)):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], linewidth=3, c=cb_dark_blue, label='Women')
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], linewidth=3, c=cb_orange, label='Men')
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom=False, top=False, left=False, right=False)

    if sp == 0:
    # for adding anotation in the picture
    # ax.text(x,y,"string")
        ax.text(2005,75,"Men")
        ax.text(2005,25,"Women")

    if sp == len(stem_cats)-1:
        ax.text(2005,65,"Men")
        ax.text(2005,35,"Women")

plt.show()

# %% [markdown]
# ## Visualization with pandas

# %%
oecd = pd.read_csv('data/OECD_data.csv')
# oecd.info()
# oecd.head()

columns_to_drop = ['INDICATOR', 'SUBJECT','FREQUENCY','MEASURE', 'Flag Codes']
oecd.drop(columns=columns_to_drop, inplace=True)

# %%
oecd.head()
# Out:
#   LOCATION  TIME  Value
# 0      AUS  1967  1.875
# 1      AUS  1968  1.850
# 2      AUS  1969  1.800
# 3      AUS  1970  1.625
# 4      AUS  1971  1.925

# %%
oecd["LOCATION"].value_counts()
# Out:
# CAN    61
# AUS    53
# AUT    50
# BEL    20
# Name: LOCATION, dtype: int64

# %% [markdown]
# ### Izrisovanje plotov direktno iz Pandas: df.plot
#
# - Plotting Version 1: .plot plots the index against every column
#
# - Plotting Version 2: .plot(x='col1') plots against a single specific column -> Več o tem naslednjič.
#
#
# - Plotting Version 3: .plot(x='col1', y='col2') plots one specific column against another specific column

# %%
# version 1
a = oecd.groupby('LOCATION')['Value'].mean().plot(kind='bar') # na nek nacin preko groupby izberemo x in y
plt.show()

# %%
# version 3 -> eksaktno preko parametrov x in y dolocimo parametre grafa
fig, ax=plt.subplots()
oecd.groupby('LOCATION').plot(x='TIME', y='Value', ax=ax, legend=False) # under the hood -> grupiranje naredi index
# dodaj legendo ?!? -> poglej predavanja
plt.show()

# %% [markdown]
# ## Seaborn

# %% [markdown]
# ### Introduction to Seaborn

# %% [markdown]
# ### Introduction to the Data Set

# %%
import pandas as pd
titanic = pd.read_csv('data/train.csv')
cols = ['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Creating Histograms In Seaborn

# %%
import seaborn as sns    # seaborn is commonly imported as `sns`
import matplotlib.pyplot as plt

# %%
sns.histplot(titanic['Fare'],kde=True, stat='percent')
# Out:
# <AxesSubplot: xlabel='Fare', ylabel='Percent'>

# %%
sns.histplot(titanic['Age'],kde=True, stat='percent') # stat percent -> glej razliko v y osi, ni count ampak procent
# kde narise se gladko trend linijo
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Percent'>

# %% [markdown]
# ### Generating A Kernel Density Plot

# %%
sns.kdeplot(titanic['Age'], fill='True')
plt.show()

# %% [markdown]
# ### Modifying The Appearance Of The Plots

# %%
# sns.set_style()

sns.set_style('white')
sns.kdeplot(titanic['Age'], fill='True')
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# ### Conditional Plots

# %%
# Condition on unique values of the "Survived" column values
g = sns.FacetGrid(titanic, col='Survived', height=4) # dva tipa preziveli/nepreziveli -> rezervira dva subplota

# For each subset of values create a certain chart
g.map(sns.kdeplot, "Age", fill=True)

# %%
# Condition on unique values of the "Survived" column values
g = sns.FacetGrid(titanic, col='Survived', height=4) # dva tipa preziveli/nepreziveli -> rezervira dva subplota

# For each subset of values create a certain chart
g.map(plt.hist, "Age") # v map lahko vstavimo tudi matplotlib grafe

# %%
g = sns.FacetGrid(titanic, col='Pclass', height=4)
# For each subset of values create a certain chart
g.map(sns.kdeplot, "Age", fill=True)

# %%
# kombiniranje 2 parametrov
g = sns.FacetGrid(titanic, col='Survived',row='Pclass', height=4)
# For each subset of values create a certain chart
g.map(sns.kdeplot, "Age", fill=True)

# %%
# kombiniranje vec parametrov + adding legend
g = sns.FacetGrid(titanic, col='Survived',row='Pclass', hue='Sex', height=4)
# For each subset of values create a certain chart
g.map(sns.kdeplot, "Age", fill=True)
g.add_legend()
plt.show()
